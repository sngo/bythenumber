# %%
import json
import pandas as pd

# %%
fileData = pd.read_csv("Daily new COVID-19 vaccination doses administered-12-21-2020-02-12-2021-v2.csv")

# %%
fileData.shape
# Out:
# (68533, 59)

# %%
fileData.head(3)
# Out:
#   iso_code continentt     location       date  total_cases  new_cases  \
# 0      AFG       Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG       Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG       Asia  Afghanistan  2/26/2020          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# 1           ...                   1803.987              NaN
# 2           ...                   1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# ...

# %%
ec = fileData['continentt'].notnull()

# %%
ec.value_counts()
# Out:
# True     65106
# False     3427
# Name: continentt, dtype: int64

# %%
#this will eliminate all the row where it is continent and world
ecdata = fileData[ec]

# %%
ecdata.shape
# Out:
# (65106, 59)

# %%
ecdata.head(3)
# Out:
#   iso_code continentt     location       date  total_cases  new_cases  \
# 0      AFG       Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG       Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG       Asia  Afghanistan  2/26/2020          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# 1           ...                   1803.987              NaN
# 2           ...                   1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# ...

# %%
vacinatedtable = ecdata[['date','continentt', 'location', 'people_vaccinated']]

# %%
vacinatedtable.head(3)
# Out:
#         date continentt     location  people_vaccinated
# 0  2/24/2020       Asia  Afghanistan                NaN
# 1  2/25/2020       Asia  Afghanistan                NaN
# 2  2/26/2020       Asia  Afghanistan                NaN

# %%
vacinatedtable.shape
# Out:
# (65106, 4)

# %%
#vaciFrom112021.to_csv('VacinatedFrom2021-01-01To2021-02-12.csv', index=False)

# %%
vacinatedtable.dtypes
# Out:
# date                 datetime64[ns]
# continentt                   object
# location                     object
# people_vaccinated           float64
# dtype: object

# %%
#convert string to date
#vacinatedtable['date'] = pd.to_datetime(vacinatedtable['date'])
vacinatedtable.head(3)
# Out:
#         date continentt     location  people_vaccinated
# 0 2020-02-24       Asia  Afghanistan                NaN
# 1 2020-02-25       Asia  Afghanistan                NaN
# 2 2020-02-26       Asia  Afghanistan                NaN

# %%
vacinatedtable.dtypes
# Out:
# date                 datetime64[ns]
# continentt                   object
# location                     object
# people_vaccinated           float64
# dtype: object

# %%
vacinatedtable.tail(5)
# Out:
#             date continentt  location  people_vaccinated
# 68528   2/8/2021     Africa  Zimbabwe                NaN
# 68529   2/9/2021     Africa  Zimbabwe                NaN
# 68530  2/10/2021     Africa  Zimbabwe                NaN
# 68531  2/11/2021     Africa  Zimbabwe                NaN
# 68532  2/12/2021     Africa  Zimbabwe                NaN

# %%
vaciFrom112021 = vacinatedtable.loc[vacinatedtable['date'] >= '2021-01-01']

# %%
vaciFrom112021.head()
# Out:
#           date continentt     location  people_vaccinated
# 312 2021-01-01       Asia  Afghanistan                NaN
# 313 2021-01-02       Asia  Afghanistan                NaN
# 314 2021-01-03       Asia  Afghanistan                NaN
# 315 2021-01-04       Asia  Afghanistan                NaN
# 316 2021-01-05       Asia  Afghanistan                NaN

# %%
vaciFrom112021.shape
# Out:
# (8327, 4)

# %%
#remove all the rows where no value of people_vaccinate, to reduce the number
vvc1 = vaciFrom112021.loc[vaciFrom112021['people_vaccinated'].notnull()]

# %%
vvc1.shape
# Out:
# (1322, 4)

# %%
vvc1.drop('continentt', axis=1)
# Out:
#             date       location  people_vaccinated
# 1041  2021-01-10        Albania                0.0
# 1043  2021-01-12        Albania              128.0
# 1044  2021-01-13        Albania              188.0
# 1045  2021-01-14        Albania              266.0
# 1046  2021-01-15        Albania              308.0
# 1047  2021-01-16        Albania              369.0
# 1048  2021-01-17        Albania              405.0
# 1049  2021-01-18        Albania              447.0
# 1050  2021-01-19        Albania              483.0
# 1051  2021-01-20        Albania              519.0
# 1052  2021-01-21        Albania              549.0
# 1064  2021-02-02        Albania              549.0
# 1071  2021-02-09        Albania              689.0
# 1758  2021-01-25        Andorra              576.0
# 1765  2021-02-01        Andorra             1036.0
# 1774  2021-02-10        Andorra             1291.0
# 2829  2021-01-20      Argentina           243539.0
# ...

# %%
vvTranspose = vvc1.pivot(index='location', columns='date', values='people_vaccinated')

# %%
vvTranspose.head(3)
# Out:
# date       2021-01-01  2021-01-02  2021-01-03  2021-01-04  2021-01-05  \
# location
# Albania           NaN         NaN         NaN         NaN         NaN
# Andorra           NaN         NaN         NaN         NaN         NaN
# Argentina         NaN         NaN         NaN         NaN         NaN
#
# date       2021-01-06  2021-01-07  2021-01-08  2021-01-09  2021-01-10  \
# location
# Albania           NaN         NaN         NaN         NaN         0.0
# Andorra           NaN         NaN         NaN         NaN         NaN
# Argentina         NaN         NaN         NaN         NaN         NaN
#
# date          ...      2021-02-03  2021-02-04  2021-02-05  2021-02-06  \
# location      ...
# Albania       ...             NaN         NaN         NaN         NaN
# Andorra       ...             NaN         NaN         NaN         NaN
# Argentina     ...        284196.0    297717.0         NaN    307501.0
#
# date       2021-02-07  2021-02-08  2021-02-09  2021-02-10  2021-02-11  \
# ...

# %%
vvTranspose.to_csv('VacinatedFrom2021-01-01To2021-02-12-v2.csv')

# %%
vvcShort.set_index()

# %%
vvc.to_csv('VacinatedFrom2021-01-01To2021-02-12-v1.csv', index=False)

# %%
vvc.transpose().to_csv('VacinatedFrom2021-01-01To2021-02-12-transposed.csv', index=False)

# %%
vvc.set_index('date', inplace=True)
vcc.transpose()
# Out:
#                          0            1            2            3      \
# date                 2/24/2020    2/25/2020    2/26/2020    2/27/2020
# continentt                Asia         Asia         Asia         Asia
# location           Afghanistan  Afghanistan  Afghanistan  Afghanistan
# people_vaccinated          NaN          NaN          NaN          NaN
#
#                          4            5            6            7      \
# date                 2/28/2020    2/29/2020     3/1/2020     3/2/2020
# continentt                Asia         Asia         Asia         Asia
# location           Afghanistan  Afghanistan  Afghanistan  Afghanistan
# people_vaccinated          NaN          NaN          NaN          NaN
#
#                          8            9        ...         68523     68524  \
# date                  3/3/2020     3/4/2020    ...      2/3/2021  2/4/2021
# continentt                Asia         Asia    ...        Africa    Africa
# ...
